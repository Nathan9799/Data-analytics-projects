# %%
import pandas as pd 
import matplotlib.pyplot as plt

df = pd.read_csv('car_data.csv')
df
# Out:
#      city_mpg                        class  combination_mpg  cylinders  \
# 0          25                  midsize car               29        4.0
# 1          26                  midsize car               30        4.0
# 2          25  small sport utility vehicle               27        4.0
# 3          26  small sport utility vehicle               29        4.0
# 4          26  small sport utility vehicle               28        4.0
# ..        ...                          ...              ...        ...
# 545        23                  compact car               27        4.0
# 546        21                  midsize car               24        6.0
# 547        21                  midsize car               24        6.0
# 548        17                  midsize car               19        8.0
# 549        17                  midsize car               19        8.0
#
#      displacement drive fuel_type  highway_mpg   make  \
# 0             2.5   fwd       gas           36  mazda
# ...

# %%
df.head()
# Out:
#    city_mpg                        class  combination_mpg  cylinders  \
# 0        25                  midsize car               29        4.0
# 1        26                  midsize car               30        4.0
# 2        25  small sport utility vehicle               27        4.0
# 3        26  small sport utility vehicle               29        4.0
# 4        26  small sport utility vehicle               28        4.0
#
#    displacement drive fuel_type  highway_mpg   make     model transmission  \
# 0           2.5   fwd       gas           36  mazda         6            m
# 1           2.5   fwd       gas           37  mazda         6            a
# 2           2.5   fwd       gas           31  mazda  cx-5 2wd            a
# 3           2.0   fwd       gas           34  mazda  cx-5 2wd            m
# 4           2.0   fwd       gas           32  mazda  cx-5 2wd            a
#
#    year
# 0  2014
# 1  2014
# 2  2014
# 3  2014
# 4  2014

# %%
df.describe()
# Out:
#          city_mpg  combination_mpg   cylinders  displacement  highway_mpg  \
# count  550.000000       550.000000  548.000000    548.000000   550.000000
# mean    21.460000        24.069091    5.315693      2.931752    28.609091
# std      8.147392         7.478369    1.759999      1.248419     6.832228
# min     11.000000        14.000000    3.000000      1.200000    18.000000
# 25%     17.000000        20.000000    4.000000      2.000000    24.000000
# 50%     20.000000        23.000000    4.000000      2.500000    28.000000
# 75%     24.000000        27.000000    6.000000      3.500000    32.000000
# max    126.000000       112.000000   12.000000      6.800000   102.000000
#
#               year
# count   550.000000
# mean   2019.000000
# std       3.165156
# min    2014.000000
# 25%    2016.000000
# 50%    2019.000000
# 75%    2022.000000
# max    2024.000000

# %%
df.isnull().sum()
# Out:
# city_mpg           0
# class              0
# combination_mpg    0
# cylinders          2
# displacement       2
# drive              0
# fuel_type          0
# highway_mpg        0
# make               0
# model              0
# transmission       0
# year               0
# dtype: int64

# %%
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
df
# Out:
#      city_mpg                           class  combination_mpg  cylinders  \
# 0          25                     midsize car               29        4.0
# 1          26                     midsize car               30        4.0
# 2          25     small sport utility vehicle               27        4.0
# 3          26     small sport utility vehicle               29        4.0
# 4          26     small sport utility vehicle               28        4.0
# 5          24     small sport utility vehicle               26        4.0
# 6          25     small sport utility vehicle               27        4.0
# 7          19                  subcompact car               22        6.0
# 8          19                  subcompact car               23        6.0
# 9          15                  subcompact car               18        8.0
# 10         18                  subcompact car               20        8.0
# 11         22     small sport utility vehicle               24        4.0
# ...

# %%
df.duplicated(keep = 'first').sum()
# Out:
# 2

# %%
duplicate_indices = df[df.duplicated()].index
duplicate_indices
# Out:
# Index([117, 119], dtype='int64')

# %%
average_city_mpg = df['city_mpg'].mean()
average_highway_mpg = df['highway_mpg'].mean()
average_combination_mpg = df['combination_mpg'].mean()

print(f'Average City MPG: {average_city_mpg:.2f}')
print(f'Average Highway MPG: {average_highway_mpg:.2f}')
print(f'Average Combined MPG: {average_combination_mpg:.2f}')
# Out:
# Average City MPG: 21.46
# Average Highway MPG: 28.61
# Average Combined MPG: 24.07

# %%
fuel_type_distribution = df['fuel_type'].value_counts()
print(fuel_type_distribution)
# Out:
# fuel_type
# gas            546
# diesel           2
# electricity      2
# Name: count, dtype: int64

# %%
fuel_type_distribution.plot(kind = 'pie',autopct='%1.1f%%', figsize=(7, 7),colors=['lightblue', 'lightgreen', 'orange'])
plt.title('Distribution of Fuel Types')
plt.show()

# %%
cylinders_fuel_efficiency = df.groupby('cylinders')[['city_mpg', 'highway_mpg','combination_mpg']].mean()
print(cylinders_fuel_efficiency)
# Out:
#             city_mpg  highway_mpg  combination_mpg
# cylinders
# 3.0        28.090909    36.272727        31.090909
# 4.0        24.077821    30.984436        26.700389
# 5.0        20.000000    28.000000        23.000000
# 6.0        18.626667    26.286667        21.506667
# 8.0        15.395833    22.635417        17.708333
# 10.0       13.000000    21.000000        15.666667
# 12.0       12.750000    19.000000        15.000000

# %%
cylinders_fuel_efficiency.plot(kind= 'bar', figsize=(10, 6), color=['lightblue', 'lightgreen', 'orange'])
plt.title('Average Fuel Efficiency By Number of Cylinders')
plt.xlabel('Number of Cylinders')
plt.ylabel('MPG')
plt.xticks(rotation = 0)
plt.show()

# %%
drivetrain_efficiency = df.groupby('drive')['combination_mpg'].mean()

drivetrain_efficiency
# Out:
# drive
# 4wd    20.761905
# awd    22.041860
# fwd    28.252809
# rwd    22.591304
# Name: combination_mpg, dtype: float64

# %%
drivetrain_efficiency.plot(kind='bar', figsize=(8, 5), color='coral')
plt.title('Average Combined MPG by Drivetrain Type')
plt.xlabel('Drivetrain Type')
plt.ylabel('Average Combined MPG')
plt.xticks(rotation=0)
plt.show()

# %%
electric_cars = df[df['fuel_type'] == 'electric']
gasoline_cars = df[df['fuel_type'] == 'gasoline']


avg_comb_mpg_electric = electric_cars['combination_mpg'].mean()
avg_comb_mpg_gasoline = gasoline_cars['combination_mpg'].mean()

print(f'Average Combined MPG for Electric Cars: {avg_comb_mpg_electric}')
print(f'Average Combined MPG for Gasoline Cars: {avg_comb_mpg_gasoline}')
# Out:
# Average Combined MPG for Electric Cars: nan
# Average Combined MPG for Gasoline Cars: nan

# %%
fuel_efficiency_trend = df.groupby('year')['combination_mpg'].mean()


print(fuel_efficiency_trend)

fuel_efficiency_trend.plot(kind='line', figsize=(10, 6), marker='o', color='blue')
plt.title('Average Fuel Efficiency Trend Over Years')
plt.xlabel('Year')
plt.ylabel('Average Combined MPG')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
# year
# 2014    21.36
# 2015    21.00
# 2016    25.88
# 2017    25.00
# 2018    23.06
# 2019    23.52
# 2020    25.92
# 2021    26.10
# 2022    25.52
# 2023    22.82
# 2024    24.58
# Name: combination_mpg, dtype: float64

# %%
displacement_trend = df.groupby('year')['displacement'].mean()

print(displacement_trend)

displacement_trend.plot(kind='line', figsize=(10, 6), marker='o', color='green')
plt.title('Average Engine Displacement Trend Over Years')
plt.xlabel('Year')
plt.ylabel('Average Displacement (L)')
plt.xticks(rotation=45)
plt.grid(True)
plt.show()
# Out:
# year
# 2014    3.514000
# 2015    4.004000
# 2016    2.961224
# 2017    2.779592
# 2018    2.920000
# 2019    3.028000
# 2020    2.360000
# 2021    2.396000
# 2022    2.466000
# 2023    3.054000
# 2024    2.764000
# Name: displacement, dtype: float64

# %%
cylinder_drivetrain_relationship = df.pivot_table(index='drive', columns='cylinders', aggfunc='size', fill_value=0)

print(cylinder_drivetrain_relationship)

cylinder_drivetrain_relationship.plot(kind='bar', figsize=(10, 6))
plt.title('Number of Cylinders by Drivetrain Type')
plt.xlabel('Drivetrain Type')
plt.ylabel('Count of Cars')
plt.xticks(rotation=45)
plt.legend(title='Number of Cylinders')
plt.grid(axis='y')
plt.show()
# Out:
# cylinders  3.0   4.0   5.0   6.0   8.0   10.0  12.0
# drive
# 4wd           0    20     0     8    14     0     0
# awd           2    89     2    71    44     6     1
# fwd          31   124     0    23     0     0     0
# rwd           0    24     0    48    38     0     3
